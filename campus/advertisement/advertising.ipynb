# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Advertising.csv')
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
f,axes = plt.subplots(2,2,figsize=(15,5),sharex=False)
sns.despine(left=True)
sns.distplot(data.Sales, color="b", ax=axes[0, 0])

sns.distplot(data.TV, color="r", ax=axes[0, 1])

sns.distplot(data.Radio, color="g", ax=axes[1, 0])

sns.distplot(data.Newspaper, color="m", ax=axes[1, 1])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7804\1486811859.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Sales, color="b", ax=axes[0, 0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7804\1486811859.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.TV, color="r", ax=axes[0, 1])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7804\1486811859.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Radio, color="g", ax=axes[1, 0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7804\1486811859.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Newspaper, color="m", ax=axes[1, 1])
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
JG1 = sns.jointplot(x="Newspaper",y= "Sales", data=data, kind='reg')

# %%
JG1 = sns.jointplot(x="TV",y= "Sales", data=data, kind='reg')

# %%
JG1 = sns.jointplot(x="Radio",y= "Sales", data=data, kind='reg')

# %%
sns.pairplot(data, height = 2, aspect = 1.5)

# %%
data.shape
# Out:
# (200, 5)

# %%
features=['TV','Radio','Newspaper']
target=['Sales']

# %%
data[features]
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data[features],data[target],test_size=0.05)

# %%
print('Train cases as below')
print('X_train shape:', X_train.shape)
print('y_train shape:',y_train.shape) 
print('Test cases as below')
print('X_train shape:', X_train.shape)
print('y_train shape:',y_train.shape)
# Out:
# Train cases as below
# X_train shape: (190, 3)
# y_train shape: (190, 1)
# Test cases as below
# X_train shape: (190, 3)
# y_train shape: (190, 1)

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression(fit_intercept=True)

# %%
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Intercept:',lr_model.intercept_)
print('Coefficients:',lr_model.coef_)
# Out:
# Intercept: [2.94209867]
# Coefficients: [[ 0.04646627  0.18418027 -0.00064171]]

# %%
y_pred_train = lr_model.predict(X_train)
y_pred_test = lr_model.predict(X_test)

# %%
from sklearn import metrics
